# %%
import json

# %% [markdown]
# # Read Data From JSON File

# %%
file=open('record.json','r')
r=file.read()
file.close()

record=json.loads(r)

# %%
record
# Out:
# {'1001': {'name': 'Bat',
#   'price': 1000,
#   'quantity': 20,
#   'mfd': '8/20',
#   'ed': '8/23'},
#  '1002': {'name': 'Ball',
#   'price': 100,
#   'quantity': 50,
#   'mfd': '9/20',
#   'ed': '9/21'},
#  '1003': {'name': 'Dairy Milk',
#   'price': 10,
#   'quantity': 100,
#   'mfd': '9/20',
#   'ed': '10/20'},
#  '1004': {'name': 'Coca Cola',
#   'price': 25,
#   'quantity': 80,
#   'mfd': '10/20',
#   'ed': '10/20'},
#  '1005': {'name': 'Lays',
#   'price': 5,
#   'quantity': 120,
#   'mfd': '8/20',
#   'ed': '9/20'},
#  '1006': {'name': 'Kurkure',
#   'price': 5,
#   'quantity': 120,
#   'mfd': '7/20',
#   'ed': '8/20'},
#  '1007': {'name': 'Pepsi',
#   'price': 30,
#   'quantity': 70,
#   'mfd': '8/20',
#   'ed': '9/20'},
#  '1008': {'name': 'Fanta',
#   'price': 30,
#   'quantity': 50,
#   'mfd': '8/20',
#   'ed': '9/20'},
#  '1009': {'name': '7up',
#   'price': 30,
#   'quantity': 40,
#   'mfd': '8/20',
#   'ed': '9/20'},
#  '1010': {'name': '5star',
#   'price': 10,
#   'quantity': 150,
#   'mfd': '8/20',
#   'ed': '8/20'},
#  '1011': {'name': 'Kitkat',
#   'price': 20,
#   'quantity': 150,
#   'mfd': '8/20',
#   'ed': '8/20'},
#  '1012': {'name': 'Pen',
#   'price': 10,
#   'quantity': 200,
#   'mfd': '8/20',
#   'ed': '8/24'},
#  '1013': {'name': 'Pencil',
#   'price': 10,
#   'quantity': 200,
#   'mfd': '8/20',
#   'ed': '8/22'},
#  '1014': {'name': 'Candy',
#   'price': 2,
#   'quantity': 400,
#   'mfd': '8/20',
#   'ed': '8/20'},
#  '1015': {'name': 'Eraser',
#   'price': 5,
#   'quantity': 200,
#   'mfd': '8/20',
#   'ed': '8/24'},
#  '1016': {'name': 'Sharpner',
#   'price': 5,
#   'quantity': 200,
#   'mfd': '820',
#   'ed': '6/24'},
#  '1017': {'name': 'Watch',
#   'price': 1500,
#   'quantity': 120,
#   'mfd': '7/20',
#   'ed': '7/22'},
#  '1018': {'name': 'Phone',
#   'price': 15000,
#   'quantity': 50,
#   'mfd': '9/20',
#   'ed': '9/22'},
#  '1019': {'name': 'Earphone',
#   'price': 500,
#   'quantity': 40,
#   'mfd': '8/20',
#   'ed': '12/20'},
#  '1020': {'name': 'Bottle',
#   'price': 100,
#   'quantity': 100,
#   'mfd': '8/20',
#   'ed': '8/21'},
#  '1021': {'name': 'Charger',
#   'price': 300,
#   'quantity': 125,
#   'mfd': '820',
#   'ed': '8/21'},
#  '1022': {'name': 'Bourbon',
#   'price': 40,
#   'quantity': 300,
#   'mfd': '8/20',
#   'ed': '8/20'},
#  '1023': {'name': 'Oreo',
#   'price': 50,
#   'quantity': 300,
#   'mfd': '8/20',
#   'ed': '8/20'},
#  '1024': {'name': 'Keyboard',
#   'price': 1800,
#   'quantity': 30,
#   'mfd': '8/20',
#   'ed': '8/22'},
#  '1025': {'name': 'Mouse',
#   'price': 500,
#   'quantity': 40,
#   'mfd': '8/20',
#   'ed': '8/21'}}

# %% [markdown]
# # Adding New Item

# %%
choice=True

while(choice):
    product_id=int(input("Enter the Product ID: "))
    if(str(product_id) in record.keys()):
        print(record[str(product_id)])
    prod_name=input("Enter the name of the product: ")
    price=int(input('Enter the Price: '))
    quantity=int(input('Enter the quantity: '))
    mfd=input("Enter the Date of Manufacture: ")
    ed=input("Enter the Expiry Date: ")

    if(str(product_id) in record.keys()):
        

        record[str(product_id)]['quantity']+=quantity
        record[str(product_id)]['mfd']=mfd
        record[str(product_id)]['ed']=ed
        print("-----------------------------------------")
        print("After Updation: ")
        print(record[str(product_id)])
        print("-----------------------------------------")
        
    else:
        record[product_id]={'name':prod_name,'price':price,'quantity':quantity,'mfd':mfd,'ed':ed}
        
    print("Do you want to add product to the inventory again? ")
    print("Type Y/y for YES and N/n for NO ")
    ch=input("Enter Y/y or N/n: ")
    if(ch=="Y" or ch=="y"):
        choice=True
    elif(ch=="N" or ch=="n"):
        choice=False
# Out:
# Enter the Product ID: 1010
# {'name': '5star', 'price': 10, 'quantity': 150, 'mfd': '8/20', 'ed': '8/20'}
# Enter the name of the product: 5star
# Enter the Price: 10
# Enter the quantity: 50
# Enter the Date of Manufacture: 9/20
# Enter the Expiry Date: 10/20
# -----------------------------------------
# After Updation:
# {'name': '5star', 'price': 10, 'quantity': 200, 'mfd': '9/20', 'ed': '10/20'}
# -----------------------------------------
# Do you want to add product to the inventory again?
# Type Y/y for YES and N/n for NO
# Enter Y/y or N/n: y
# Enter the Product ID: 1026
# Enter the name of the product: Ring
# Enter the Price: 1000
# Enter the quantity: 10
# Enter the Date of Manufacture: 8/20
# Enter the Expiry Date: 9/23
# Do you want to add product to the inventory again?
# Type Y/y for YES and N/n for NO
# Enter Y/y or N/n: y
# Enter the Product ID: 1015
# {'name': 'Eraser', 'price': 5, 'quantity': 200, 'mfd': '8/20', 'ed': '8/24'}
# Enter the name of the product: Eraser
# Enter the Price: 5
# Enter the quantity: 60
# Enter the Date of Manufacture: 9/20
# Enter the Expiry Date: 9/24
# -----------------------------------------
# After Updation:
# {'name': 'Eraser', 'price': 5, 'quantity': 260, 'mfd': '9/20', 'ed': '9/24'}
# -----------------------------------------
# Do you want to add product to the inventory again?
# Type Y/y for YES and N/n for NO
# Enter Y/y or N/n: y
# Enter the Product ID: 1027
# Enter the name of the product: Torch
# Enter the Price: 500
# Enter the quantity: 40
# Enter the Date of Manufacture: 8/20
# Enter the Expiry Date: 8/21
# Do you want to add product to the inventory again?
# Type Y/y for YES and N/n for NO
# Enter Y/y or N/n: y
# Enter the Product ID: 1028
# Enter the name of the product: Notebook
# Enter the Price: 50
# Enter the quantity: 35
# Enter the Date of Manufacture: 8/20
# Enter the Expiry Date: 8/22
# Do you want to add product to the inventory again?
# Type Y/y for YES and N/n for NO
# Enter Y/y or N/n: y
# Enter the Product ID: 1029
# Enter the name of the product: Calculator
# Enter the Price: 1000
# Enter the quantity: 15
# Enter the Date of Manufacture: 8/20
# Enter the Expiry Date: 8/22
# Do you want to add product to the inventory again?
# Type Y/y for YES and N/n for NO
# Enter Y/y or N/n: y
# Enter the Product ID: 1030
# Enter the name of the product: Chair
# Enter the Price: 1000
# Enter the quantity: 45
# Enter the Date of Manufacture: 8/20
# Enter the Expiry Date: 9/23
# Do you want to add product to the inventory again?
# Type Y/y for YES and N/n for NO
# Enter Y/y or N/n: n

# %% [markdown]
# # Updating Inventory after addition

# %%
js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
